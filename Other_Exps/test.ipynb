# %%
import tensorflow as tf

# %%
from tensorflow import keras
import pandas as pd

# %%
testdata = pd.read_csv('./datasets/test/_annotations.csv')
traindata = pd.read_csv('./datasets/train/_annotations.csv')
validdata = pd.read_csv('./datasets/valid/_annotations.csv')

# %%
testdata
# Out:
#                                               filename  width  height  \
# 0    Screen-Shot-2022-02-14-at-1-09-28-PM_png.rf.00...    640     640
# 1    egohands-public-1623358709389_png_jpg.rf.01566...    640     640
# 2    20220216_221550_jpg.rf.02a071a383151953fcf8671...    640     640
# 3    zoom_tests_RockPaperScissors-mohamed_mp4-87_jp...    640     640
# 4    egohands-public-1622730832103_png_jpg.rf.11458...    640     640
# ..                                                 ...    ...     ...
# 212  Screen-Recording-2023-03-11-at-9_48_18-PM_mov-...    640     640
# 213  Screen-Recording-2023-03-11-at-9_48_18-PM_mov-...    640     640
# 214  IMG_7079_MOV-8_jpg.rf.f6ecee3ccaaba4956faf5a4a...    640     640
# 215  zoom_tests_RockPaperScissors-mohamed_mp4-137_j...    640     640
# 216  egohands-public-1621214710295_png_jpg.rf.f776c...    640     640
#
#         class  xmin  ymin  xmax  ymax
# 0       Paper     0    73   156   483
# 1       Paper   131    40   277   234
# 2    Scissors   137   321   531   479
# 3        Rock    22   250   258   640
# 4    Scissors   388    24   634   264
# ..        ...   ...   ...   ...   ...
# 212      Rock   362   254   381   288
# 213      Rock   251   263   273   311
# 214      Rock    25   260   345   498
# 215     Paper   211    85   385   608
# 216     Paper   281   463   470   607
#
# [217 rows x 8 columns]

# %%
import cv2
import matplotlib.pyplot as plt

# %%
y_train = traindata[['xmin', 'ymin', 'xmax', 'ymax']]
y_test = testdata[['xmin', 'ymin', 'xmax', 'ymax']]
y_valid = validdata[['xmin', 'ymin', 'xmax', 'ymax']]
y_test
# Out:
#      xmin  ymin  xmax  ymax
# 0       0    73   156   483
# 1     131    40   277   234
# 2     137   321   531   479
# 3      22   250   258   640
# 4     388    24   634   264
# ..    ...   ...   ...   ...
# 212   362   254   381   288
# 213   251   263   273   311
# 214    25   260   345   498
# 215   211    85   385   608
# 216   281   463   470   607
#
# [217 rows x 4 columns]

# %%
def process_image(row, folder):
    image_path = './datasets/' + folder + '/' + row['filename']
    img = cv2.imread(image_path)
    # img = cv2.rectangle(img, (row['xmin'], row['ymin']), (row['xmax'], row['ymax']), (0, 255, 0), 2)
    # img_cropped = img[row['ymin']:row['ymax'], row['xmin']:row['xmax']]
    img_resized = cv2.resize(img, (32, 32))
    return img_resized

# %%
testdf = testdata.apply(process_image, axis=1, args=("test",))

# %%
testdf
# Out:
# 0      [[[219, 219, 219], [73, 73, 73], [6, 6, 6], [7...
# 1      [[[85, 90, 59], [91, 69, 19], [100, 74, 18], [...
# 2      [[[115, 185, 208], [119, 198, 219], [128, 206,...
# 3      [[[101, 118, 121], [113, 126, 125], [150, 153,...
# 4      [[[75, 78, 62], [67, 74, 59], [71, 77, 60], [6...
#                              ...
# 212    [[[132, 137, 128], [185, 189, 178], [187, 191,...
# 213    [[[132, 137, 128], [185, 189, 178], [187, 191,...
# 214    [[[207, 72, 164], [208, 74, 164], [210, 74, 16...
# 215    [[[96, 111, 110], [120, 126, 125], [143, 147, ...
# 216    [[[223, 218, 218], [148, 137, 137], [123, 109,...
# Length: 217, dtype: object

# %%
traindf = traindata.apply(process_image, axis=1, args=("train",))

# %%
validdf = validdata.apply(process_image, axis=1, args=("valid",))

# %%
import numpy as np
testdf = testdf.to_numpy()
testdf = [tf.convert_to_tensor(item) for item in testdf]
testdf = tf.convert_to_tensor(testdf)

# %%
traindf = traindf.to_numpy()

# %%
traindf = [tf.convert_to_tensor(item) for item in traindf]
traindf = tf.convert_to_tensor(traindf)

# %%
validdf = validdf.to_numpy()

# %%
validdf = [tf.convert_to_tensor(item) for item in validdf]
validdf = tf.convert_to_tensor(validdf)

# %%
x_train, x_test, x_valid = traindf/255 , testdf/255 , validdf/255

# %%
x_train.shape
# Out:
# TensorShape([7821, 32, 32, 3])

# %%
from tensorflow.keras import layers , models

# %% [markdown]
# ### Trying Something New -> Wait for it

# %%
import numpy as np



def iou_calc(true_bbox , selectivesarch_bbox):
    true_xmin, true_ymin, true_width, true_height  = true_bbox
    bb_xmin, bb_ymin,  bb_width, bb_height = selectivesarch_bbox

    true_xmax = true_xmin + true_width
    true_ymax = true_ymin + true_height
    bb_xmax = bb_xmin + bb_width
    bb_ymax = bb_ymin + bb_height

    #calculating area
    true_area = true_width * true_height
    bb_area   = bb_width * bb_height 

    #calculating itersection cordinates
    inter_xmin = max(true_xmin , bb_xmin) 
    inter_ymin = max(true_ymin , bb_ymin)
    inter_xmax = min(true_xmax , bb_xmax)
    inter_ymax = min(true_ymax , bb_ymax)

    if inter_xmax <= inter_xmin or inter_ymax <= inter_ymin:
        iou = 0


    else:
        inter_area = (inter_xmax - inter_xmin) * (inter_ymax - inter_ymin)


        iou = inter_area / (true_area + bb_area - inter_area)
        
    assert iou<=1
    assert iou>=0
    
    return iou

# %%
import cv2

# %%
cv2.setUseOptimized(True)
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-contrib-python in g:\anaconda\lib\site-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in g:\anaconda\lib\site-packages (from opencv-contrib-python) (1.24.3)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# g:\Final_AI\test.ipynb Cell 23 line 3
#       <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#X31sZmlsZQ%3D%3D?line=0'>1</a> cv2.setUseOptimized(True)
#       <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#X31sZmlsZQ%3D%3D?line=1'>2</a> get_ipython().run_line_magic('pip', 'install opencv-contrib-python')
# ----> <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#X31sZmlsZQ%3D%3D?line=2'>3</a> ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()
#
# AttributeError: module 'cv2' has no attribute 'ximgproc'

# %%
image_path = './datasets/' + 'test' + '/' + 'youtube-25_jpg.rf.121bbf3873487349ba7e5e2cde55dcef.jpg'
img = cv2.imread(image_path)
img = cv2.resize(img, (240, 240))
ss.setBaseImage(img)
ss.switchToSelectiveSearchFast()

# %%
import matplotlib.pyplot as plt

# %%
rects = ss.process()

# %%
sel_rects = rects[:1200]
imOut = img.copy()
for i, rect in (enumerate(sel_rects)):
    x, y, w, h = rect
    cv2.rectangle(imOut, (x, y), (x+w, y+h), (0, 255, 0), 1, cv2.LINE_AA)
plt.figure(figsize=(8,8))
plt.imshow(imOut)

# %%
import pandas as pd
import numpy as np
import cv2

cv2.setUseOptimized(True)
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()


def iou_filter(image_path,img_name,true_bb,thresh=0.5):
    print(image_path)
    img_bb = true_bb[true_bb['filename']==img_name].reset_index(drop=True)
    img = cv2.imread(image_path)
    ss.setBaseImage(img)
    ss.switchToSelectiveSearchFast()
    rects = ss.process()
    ss_bb = rects[:2000]
    filtered_selective_search = []
    negative_examples = []
    maybe_neagative = []
    
    # loop to compute iou for all label of perticular image
    for label in range(len(img_bb)):
        

        #unpacking cordinates
        true_xmin, true_ymin, true_width, true_height  = img_bb.loc[label,'xmin'], img_bb.loc[label,'ymin'], img_bb.loc[label,'xmax']-img_bb.loc[label,'xmin'], img_bb.loc[label,'ymax']-img_bb.loc[label,'ymin']
        class_of_label = img_bb.loc[label,'class']
        
        #loop to compute iou for all selective search of perticular label
        for j,rect in enumerate(ss_bb):
            calculating_iou_for_selectivesearch = iou_calc([true_xmin, true_ymin, true_width, true_height],rect)
            
            if calculating_iou_for_selectivesearch > thresh:
                filtered_selective_search.append([list(rect),class_of_label])
            
            elif calculating_iou_for_selectivesearch <0.5:
                maybe_neagative.append(list(rect))
    
    #removing duplicate entries
    
    def Remove(duplicate): 
        final_list = [] 
        for num in duplicate: 
            if num not in final_list: 
                final_list.append(num) 
        return final_list 

    maybe_neagative = Remove(maybe_neagative)
    filtered_selective_search = Remove(filtered_selective_search)
   

    #this is will use for background class for CNN which has iou less than 0.2, In paper it's 0.3 but in that also written that it's depends on dataset. 

    only_labels_of_filtered_selective_search = [x[0] for x in filtered_selective_search]

    for lab in maybe_neagative:
        condition = []    
        for true_lab in only_labels_of_filtered_selective_search:
            
            iou_for_negative_ex = iou_calc(true_lab,lab)
            
            condition.append(True) if iou_for_negative_ex <= 0.5  else condition.append(False)

        if False not in condition:
            negative_examples.append(lab)
    
    negative_examples = Remove(negative_examples)
    random_background_images_index = np.random.randint(low=0, high=len(negative_examples), size=2*len(only_labels_of_filtered_selective_search)) 
    random_background_images = [negative_examples[x] for x in random_background_images_index]

    
    return filtered_selective_search , Remove(random_background_images)

# %%
image_path2 = './datasets/' + 'train' + '/' + '0031_png.rf.01ee1fffe08da1e95a3c89e8d2f11711.jpg'
imagetestde = '0031_png.rf.01ee1fffe08da1e95a3c89e8d2f11711.jpg'

# %%
cs,neg =iou_filter(image_path2,imagetestde,traindata,thresh=0.55)
# Out:
# ./datasets/train/0031_png.rf.01ee1fffe08da1e95a3c89e8d2f11711.jpg

# %%
cs
# Out:
# [[[203, 332, 49, 103], 'Scissors'],
#  [[202, 341, 45, 94], 'Scissors'],
#  [[202, 336, 52, 109], 'Scissors'],
#  [[194, 332, 58, 103], 'Scissors'],
#  [[165, 341, 82, 94], 'Scissors'],
#  [[302, 400, 108, 74], 'Scissors'],
#  [[297, 395, 121, 129], 'Scissors'],
#  [[301, 399, 106, 91], 'Scissors'],
#  [[302, 401, 106, 90], 'Scissors'],
#  [[302, 401, 106, 88], 'Scissors'],
#  [[306, 403, 104, 86], 'Scissors'],
#  [[278, 374, 140, 116], 'Scissors'],
#  [[297, 395, 98, 99], 'Scissors'],
#  [[306, 403, 104, 71], 'Scissors'],
#  [[300, 399, 107, 93], 'Scissors'],
#  [[302, 401, 96, 88], 'Scissors'],
#  [[303, 400, 104, 92], 'Scissors'],
#  [[282, 386, 113, 108], 'Scissors'],
#  [[308, 400, 99, 92], 'Scissors'],
#  [[300, 420, 95, 74], 'Scissors'],
#  [[308, 400, 99, 90], 'Scissors'],
#  [[295, 396, 123, 94], 'Scissors'],
#  [[297, 395, 121, 128], 'Scissors'],
#  [[306, 403, 104, 87], 'Scissors'],
#  [[301, 399, 117, 91], 'Scissors'],
#  [[306, 403, 112, 86], 'Scissors'],
#  [[302, 400, 116, 109], 'Scissors'],
#  [[299, 416, 96, 78], 'Scissors'],
#  [[309, 398, 109, 125], 'Scissors'],
#  [[302, 400, 105, 90], 'Scissors'],
#  [[297, 395, 110, 99], 'Scissors'],
#  [[297, 395, 121, 99], 'Scissors'],
#  [[302, 401, 96, 90], 'Scissors'],
#  [[301, 399, 117, 124], 'Scissors'],
#  [[295, 396, 115, 94], 'Scissors'],
#  [[302, 400, 108, 90], 'Scissors'],
#  [[300, 399, 118, 93], 'Scissors'],
#  [[306, 403, 112, 87], 'Scissors'],
#  [[295, 396, 113, 95], 'Scissors'],
#  [[282, 370, 113, 124], 'Scissors'],
#  [[295, 396, 113, 93], 'Scissors'],
#  [[295, 396, 123, 96], 'Scissors'],
#  [[282, 370, 121, 124], 'Scissors'],
#  [[295, 396, 123, 127], 'Scissors'],
#  [[295, 396, 115, 97], 'Scissors']]

# %%
img = cv2.imread(image_path2)
for i, rect in (enumerate(cs)):
    x, y, w, h = rect[0]
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2, cv2.LINE_AA)
    
plt.figure(figsize=(12,8))
plt.imshow(img)

# %%
len(cs)
# Out:
# 45

# %%
len(neg)
# Out:
# 88

# %%
img = cv2.imread(image_path2)
for i, rect in (enumerate(neg)):
    x, y, w, h = rect
    
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2, cv2.LINE_AA)
    
    
plt.figure(figsize=(12,8))
plt.imshow(img)

# %%
train_data = {}
test_data  = {}

# %%
path2 = './datasets/' + 'train' + '/'

# %%
itr_arr = []
for file_path in traindata['filename']:
    itr_arr.append(file_path)
itr_arr
# Out:
# ['zoom_tests_RockPaperScissors-mohamed_mp4-67_jpg.rf.000c94da234525180bcf003ce05e8ea1.jpg',
#  'egohands-public-1625070649053_png_jpg.rf.000a5110e86a581124b82143dde75594.jpg',
#  'zoom_tests_RockPaperScissors-mohamed_mp4-111_jpg.rf.0026014f030bc8948f695c72e7da80cb.jpg',
#  'IMG_5636_MOV-61_jpg.rf.003476f680b71b74f3764a14153a634a.jpg',
#  'IMG_5636_MOV-61_jpg.rf.003476f680b71b74f3764a14153a634a.jpg',
#  'egohands-public-1626201626932_png_jpg.rf.001f745e10caeb2be82294d9ec919dc0.jpg',
#  'IMG_7077_MOV-88_jpg.rf.00235d8ae3c3ac4a618ddde10a32c229.jpg',
#  'IMG_7077_MOV-88_jpg.rf.00235d8ae3c3ac4a618ddde10a32c229.jpg',
#  'IMG_7043_MOV-71_jpg.rf.0059209d24d383f7ac8f635535fb72ee.jpg',
#  'scissors_jpg.rf.432651b104552c157f606e14656b19ec.jpg',
#  'scissors_jpg.rf.432651b104552c157f606e14656b19ec.jpg',
#  'scissors_jpg.rf.432651b104552c157f606e14656b19ec.jpg',
#  'youtube-89_jpg.rf.43098d637f7493b12892aad77808e5ae.jpg',
#  'youtube-89_jpg.rf.43098d637f7493b12892aad77808e5ae.jpg',
#  'egohands-public-1623941905051_png_jpg.rf.43507fba2d0df140a11b298411774eb5.jpg',
#  '0005_png.rf.4347b42966241ac67ec30896a21495a7.jpg',
#  '0005_png.rf.4347b42966241ac67ec30896a21495a7.jpg',
#  'Screen-Recording-2023-03-11-at-9_48_18-PM_mov-208_jpg.rf.434c9d0b3eba3afad465ba699080c12e.jpg',
#  'Screen-Recording-2023-03-11-at-9_48_18-PM_mov-208_jpg.rf.434c9d0b3eba3afad465ba699080c12e.jpg',
#  'egohands-public-1620849827096_png_jpg.rf.436a3299396d8575bfb2b3d8f5bc6f6e.jpg',
#  'zoom_tests_RockPaperScissors-mohamed_mp4-109_jpg.rf.436391d360d5436f4341d9edd761a3af.jpg',
#  'Photo-on-2-16-22-at-10-20-AM-13_jpg.rf.436d1ba2da189fe77d76397d1ca973a1.jpg',
#  '0045_png.rf.436abfd426127a0665e0722917de17b5.jpg',
#  '0045_png.rf.436abfd426127a0665e0722917de17b5.jpg',
#  'Screen-Shot-2021-05-12-at-3-33-32-PM_png_jpg.rf.433a2af1cb30abf514dbb080569673eb.jpg',
#  '0155_png.rf.43299330ac19cf0764a8aea775b3428b.jpg',
#  '0155_png.rf.43299330ac19cf0764a8aea775b3428b.jpg',
#  'egohands-public-1621214708794_png_jpg.rf.4374f019951ff9c3bdd02b8979274c94.jpg',
#  'IMG_7043_MOV-176_jpg.rf.4390725e90c7befa87d847d46f380813.jpg',
#  'IMG_5636_MOV-21_jpg.rf.43a4bdeb41f3124de5a763d705a4f7d9.jpg',
#  'egohands-public-1620850501554_png_jpg.rf.43b31fc358a12234a8f3624c1f49d1b5.jpg',
#  'IMG_7043_MOV-49_jpg.rf.43a982bd666ca356ed717e1d6e6ac516.jpg',
#  'egohands-public-1624550292085_png_jpg.rf.43979d208f793b43662f986f1194c1ed.jpg',
#  'youtube-128_jpg.rf.43a653e6a7ae512c53b9c4bd05aec944.jpg',
#  '0278_png.rf.43b0b1fa485fcd76111302fb6dbda2b5.jpg',
#  '0278_png.rf.43b0b1fa485fcd76111302fb6dbda2b5.jpg',
#  ...]

# %%
events_count = len(itr_arr[:10])
for i in range(events_count):
    cs, neg = iou_filter(path2 + itr_arr[i], itr_arr[i] ,traindata, thresh=0.5)
    train_data[itr_arr[i]] = {'region_proposal':cs,'negative_example':neg}
    finished = 100*(i/events_count)
    print(finished)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# g:\Final_AI\test.ipynb Cell 39 line 3
#       <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#X53sZmlsZQ%3D%3D?line=0'>1</a> events_count = len(itr_arr[:10])
#       <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#X53sZmlsZQ%3D%3D?line=1'>2</a> for i in range(events_count):
# ----> <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#X53sZmlsZQ%3D%3D?line=2'>3</a>     cs, neg = iou_filter(path2 + itr_arr[i], itr_arr[i] ,traindata, thresh=0.5)
#       <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#X53sZmlsZQ%3D%3D?line=3'>4</a>     train_data[itr_arr[i]] = {'region_proposal':cs,'negative_example':neg}
#       <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#X53sZmlsZQ%3D%3D?line=4'>5</a>     finished = 100*(i/events_count)
#
# NameError: name 'iou_filter' is not defined

# %%
train_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# g:\Final_AI\test.ipynb Cell 40 line 1
# ----> <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#X54sZmlsZQ%3D%3D?line=0'>1</a> train_data
#
# NameError: name 'train_data' is not defined

# %%
# def is_collision(rect1, rect2):
#     x1 = rect1[0]
#     y1 = rect1[1]
#     w1 = rect1[2]
#     h1 = rect1[3]
#     x2 = rect2[0]
#     y2 = rect2[1]
#     w2 = rect2[2]
#     h2 = rect2[3]
#     return (
#         x1 < x2 + w2 and
#         x1 + w1 > x2 and
#         y1 < y2 + h2 and
#         y1 + h1 > y2
#     )

# def do_rectangles_collide(rect1, rect2):
#     x1, y1, width1, height1 = rect1
#     x2, y2, width2, height2 = rect2

#     # Calculate the right and bottom coordinates of each rectangle
#     right1 = x1 + width1
#     bottom1 = y1 + height1
#     right2 = x2 + width2
#     bottom2 = y2 + height2

#     # Check for collision
#     if (x1 > right2) or (x2 > right1) or (y1 > bottom2) or (y2 > bottom1):
#         return False
#     else:
#         return True

# def remove_collisions(rectangles):
#     non_colliding_rectangles = []
#     for i, rect1 in enumerate(rectangles):
#         is_colliding = False
#         # print('rect1')
#         # print(rect1)
#         for j, rect2 in enumerate(rectangles):
#             # print('rect2')
#             # print(rect2)
#             if i != j and do_rectangles_collide(rect1, rect2):
#                 is_colliding = True
#                 break
#         if not is_colliding:
#             non_colliding_rectangles.append(rect1)
#     return non_colliding_rectangles


def do_rectangles_collide(rect1, rect2):
    x1, y1, width1, height1 = rect1
    x2, y2, width2, height2 = rect2
    # Calculate the right and bottom coordinates of each rectangle
    right1 = x1 + width1
    bottom1 = y1 + height1
    right2 = x2 + width2
    bottom2 = y2 + height2
    if (x1 >= right2) or (x2 >= right1) or (y1 >= bottom2) or (y2 >= bottom1):
        return False
    else:
        return True


def remove_collisions(rectangles):
    non_colliding_rectangles = []
    for i, rect1 in enumerate(rectangles):
        is_colliding = False
        for j in range(i + 1, len(rectangles)):
            rect2 = rectangles[j]
            if do_rectangles_collide(rect1, rect2):
                is_colliding = True
                break
        if not is_colliding:
            non_colliding_rectangles.append(rect1)
    return non_colliding_rectangles

# %%
# region_proposals = train_data[itr_arr[0]]['region_proposal']
# bounding_boxes = [entry[0] for entry in region_proposals]
x_min = 640
y_min = 640
x_max = 0
y_max = 0

xt = 6

arrr = []


img22 = cv2.imread(path2 + itr_arr[xt])
for i, rect in (enumerate(train_data[itr_arr[xt]]['region_proposal'])):
    arrr.append(rect)
    x = rect[0][0]
    y = rect[0][1]
    w = rect[0][2]
    h = rect[0][3]
    x_min = min(x_min, x)
    y_min = min(y_min, y)
    x_max = max(x_max, x+ w)
    y_max = max(y_max, y + h)
    
    
    cv2.rectangle(img22, (x, y), (x+w, y+h), (0, 255, 0), 2, cv2.LINE_AA)
    

print(arrr)
# cv2.rectangle(img22, (x_min, y_min), (x_max, y_max), (255, 0, 0), 2, cv2.LINE_AA)
    
plt.figure(figsize=(12,8))
plt.imshow(img22)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# g:\Final_AI\test.ipynb Cell 42 line 1
#      <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#X56sZmlsZQ%3D%3D?line=9'>10</a> arrr = []
#      <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#X56sZmlsZQ%3D%3D?line=12'>13</a> img22 = cv2.imread(path2 + itr_arr[xt])
# ---> <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#X56sZmlsZQ%3D%3D?line=13'>14</a> for i, rect in (enumerate(train_data[itr_arr[xt]]['region_proposal'])):
#      <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#X56sZmlsZQ%3D%3D?line=14'>15</a>     arrr.append(rect)
#      <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#X56sZmlsZQ%3D%3D?line=15'>16</a>     x = rect[0][0]
#
# NameError: name 'train_data' is not defined

# %%
rectangles_list = [item[0] for item in arrr]
print(rectangles_list)
# Out:
# []

# %%
# remove_collisions(rectangles_list)
non_colliding_rect = remove_collisions(rectangles_list)
img23 = cv2.imread(path2 + itr_arr[6])
# non_colliding_rect
for j, rect2 in enumerate(non_colliding_rect):
    x, y, w, h = rect2
    cv2.rectangle(img23, (x, y), (x+w, y+h), (0, 255, 0), 2, cv2.LINE_AA)

plt.figure(figsize=(12,8))
plt.imshow(img23)

# %%
itr_arr1 = []
for file_path in testdata['filename']:
    itr_arr.append(file_path)
itr_arr1
# Out:
# []

# %%
path3 = './datasets/' + 'test' + '/'

# %%
events_count1 = len(itr_arr1)
for i in range(events_count1):
    cs1, neg1 = iou_filter(path3 + itr_arr1[i], itr_arr1[i] ,testdata, thresh=0.5)
    test_data[itr_arr1[i]] = {'region_proposal':cs1,'negative_example':neg1}
    finished = 100*(i/events_count1)
    print(finished)

# %%
import json
class MyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(MyEncoder, self).default(obj)

# %%
with open('train.json','w+') as output_file:
    json.dump(train_data,output_file,cls=MyEncoder)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# g:\Final_AI\test.ipynb Cell 49 line 2
#       <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#X66sZmlsZQ%3D%3D?line=0'>1</a> with open('train.json','w+') as output_file:
# ----> <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#X66sZmlsZQ%3D%3D?line=1'>2</a>     json.dump(train_data,output_file,cls=MyEncoder)
#
# NameError: name 'train_data' is not defined

# %%
with open('test.json','w+') as output_file:
    json.dump(test_data,output_file,cls=MyEncoder)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# g:\Final_AI\test.ipynb Cell 50 line 2
#       <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#Y100sZmlsZQ%3D%3D?line=0'>1</a> with open('test.json','w+') as output_file:
# ----> <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#Y100sZmlsZQ%3D%3D?line=1'>2</a>     json.dump(test_data,output_file,cls=MyEncoder)
#
# NameError: name 'test_data' is not defined

# %%
with open('train.json') as train:
    train_json = json.load(train)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# g:\Final_AI\test.ipynb Cell 51 line 2
#       <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#Y101sZmlsZQ%3D%3D?line=0'>1</a> with open('train.json') as train:
# ----> <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#Y101sZmlsZQ%3D%3D?line=1'>2</a>     train_json = json.load(train)
#
# File g:\anaconda\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File g:\anaconda\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File g:\anaconda\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File g:\anaconda\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
with open('test.json') as test:
    test_json = json.load(test)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# g:\Final_AI\test.ipynb Cell 52 line 2
#       <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#Y102sZmlsZQ%3D%3D?line=0'>1</a> with open('test.json') as test:
# ----> <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#Y102sZmlsZQ%3D%3D?line=1'>2</a>     test_json = json.load(test)
#
# File g:\anaconda\Lib\json\__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File g:\anaconda\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File g:\anaconda\Lib\json\decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File g:\anaconda\Lib\json\decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
train_json == train_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# g:\Final_AI\test.ipynb Cell 53 line 1
# ----> <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#Y103sZmlsZQ%3D%3D?line=0'>1</a> train_json == train_data
#
# NameError: name 'train_json' is not defined

# %%
test_json == test_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# g:\Final_AI\test.ipynb Cell 54 line 1
# ----> <a href='vscode-notebook-cell:/g%3A/Final_AI/test.ipynb#Y104sZmlsZQ%3D%3D?line=0'>1</a> test_json == test_data
#
# NameError: name 'test_json' is not defined
